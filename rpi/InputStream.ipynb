# %%
from hume import HumeVoiceClient, MicrophoneInterface
from dotenv import load_dotenv
import os
import websockets
import base64
import wave
import json
import asyncio
from pydub import AudioSegment
from io import BytesIO

load_dotenv()

from VoiceActivityDetector import VoiceActivityDetector
from openai import AsyncOpenAI

client = AsyncOpenAI()

import nest_asyncio 
nest_asyncio.apply()
# Out:
# Start speaking.

# %%
async def text_chunker(chunks):
    """Yield complete sentences from streamed text input."""
    sentence_endings = (".", "?", "!")
    buffer = ""

    async for text in chunks:
        message = text.choices[0].delta.content
        if message == None:
            continue
        buffer += message

        # Find the last occurrence of any sentence-ending punctuation in the buffer
        last_punct = max(buffer.rfind(punct) for punct in sentence_endings)

        if last_punct != -1:
            # If there is sentence-ending punctuation, split at the last punctuation
            sentence = buffer[: last_punct + 1]  # Include the punctuation in the output
            yield sentence
            buffer = buffer[
                last_punct + 1 :
            ].strip()  # Save what's after the punctuation into the buffer

    # If there's any remaining text in the buffer after the loop, yield it
    if buffer:
        yield buffer

# %%
async def websocket_send(websocket, model_generator):
    # Iterate over the asynchronous generator from the OpenAI API
    async for message in text_chunker(model_generator):
        print("Sent message:", message)
        # Here, we're assuming message has a structure we can directly send
        await websocket.send(
            json.dumps(
                {"type": "assistant_input", "text": message}
            )
        )

# %%
async def receive_and_save_audio(websocket, filename):
    # Set up the WAV file for writing audio output
    audiosegment = AudioSegment.empty()
    try:
        async for message in websocket:
            print("Received message")
            data = json.loads(message)
            if data["type"] == "audio_output":
                # Convert base64 audio data to bytes
                data = base64.b64decode(data["data"])
                audiosegment += AudioSegment.from_file(BytesIO(data))
            else:
                print("Received non-audio message")
    finally:
        audiosegment.export(filename, format="wav")

# %%
HUME_API_KEY = os.getenv("HUME_API_KEY")
websocket_url = f"wss://api.hume.ai/v0/evi/chat?api_key={HUME_API_KEY}"
wave_file = "test.wav"
async with websockets.connect(websocket_url) as websocket:
    response = await client.chat.completions.create(
        model="gpt-4-turbo",
        stream=True,
        max_tokens=500,
        messages=[
            {"role": "system", "content": "You are a storyteller."},
            {
                "role": "user",
                "content": "Tell me a emotional short story about a ship for a four year old.",
            },
        ],
    )

    sender_task = asyncio.create_task(websocket_send(websocket, response))
    receiver_task = asyncio.create_task(receive_and_save_audio(websocket, wave_file))
    await asyncio.gather(sender_task, receiver_task)
# Out:
# Sent message: Once upon a time, there was a small, blue wooden ship named Sally.
# Sent message:  Sally wasn't like the big ships that carried cars or the tall ships that had many sails.
# Received message
# Received non-audio message
# Received message
# Sent message:  She was a simple ship, perfect for bobbing along the gentle rivers and exploring the hidden secrets of the water.
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Sent message: Sally had one very special friend, Timmy, a cheerful little boy with a wide smile and sparkly eyes.
# Received message
# Received non-audio message
# Received message
# Sent message:  Every summer, Timmy would come to the river with his grandpa, and the first thing he would do was run to Sally, greeting her with a big, warm hug.
# Sent message: "Hello Sally!
# Sent message:  Are you ready for an adventure?
# Sent message: " Timmy would shout, and it seemed like Sally shook her mast in excitement.
# Received message
# Received non-audio message
# Sent message: Together, they would sail gently down the river.
# Received message
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Sent message:  Timmy would giggle as the water splashed softly against Sally's wooden sides, and he would tell her all about his dreams, his favorite toys, and the stories from school.
# Received message
# Received non-audio message
# Received message
# Sent message: But one summer, when Timmy came to the river, he noticed that Sally looked a bit sad.
# Sent message:  Her paint was peeling, and she didn't bob as cheerfully as before.
# Received message
# Received non-audio message
# Sent message:  Seeing his dear friend like this, Timmy felt a tear roll down his cheek.
# Sent message: "What’s wrong, Sally?
# Sent message: " Timmy asked softly, laying his hand on her deck.
# Sent message: Sally couldn’t speak, but Timmy understood.
# Received message
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Sent message:  She felt old and wasn’t sure she could carry Timmy for adventures anymore.
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Sent message:  Timmy hugged Sally tight and said, "Don't worry, I'll help you feel better!
# Received message
# Received non-audio message
# Received message
# Sent message: "With the help of his grandpa, Timmy spent the whole day painting Sally in bright, beautiful colors.
# Received message
# Received non-audio message
# Received message
# Sent message:  They patched up her little scrapes and made sure she was as sturdy as ever.
# Received message
# Received non-audio message
# Received message
# Sent message:  As they worked, Timmy told Sally all the stories he had saved up from the last year, making Sally feel loved and important.
# Received message
# Received non-audio message
# Received message
# Sent message: When they were done, Sally looked brighter and happier than ever.
# Sent message:  She felt young again and ready to sail.
# Received message
# Received non-audio message
# Received message
# Sent message:  Timmy jumped aboard and said, "Now, let’s go find some new adventures!
# Received message
# Received non-audio message
# Received message
# Sent message: " Sally, feeling sprightly and new, glided smoothly on the river, carrying her best friend wherever he wished to go.
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Sent message: From that day on, Sally and Timmy learned that no matter how old or worn they felt, their friendship would always renew them.
# Received message
# Received non-audio message
# Received message
# Sent message:  They had many more adventures, and with each one, their bond grew stronger.
# Sent message: And so, Sally the ship and Timmy the boy spent many joyful
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# Received message
# Received message
# Received non-audio message
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# File ~/miniconda3/envs/experiments/lib/python3.10/asyncio/tasks.py:234, in Task.__step(***failed resolving arguments***)
#     233     else:
# --> 234         result = coro.throw(exc)
#     235 except StopIteration as exc:
#
# Cell In[8], line 5, in receive_and_save_audio(websocket, filename)
#       4 try:
# ----> 5     async for message in websocket:
#       6         print("Received message")
#
# File ~/miniconda3/envs/experiments/lib/python3.10/site-packages/websockets/legacy/protocol.py:498, in WebSocketCommonProtocol.__aiter__(self)
#     497     while True:
# --> 498         yield await self.recv()
#     499 except ConnectionClosedOK:
#
# File ~/miniconda3/envs/experiments/lib/python3.10/site-packages/websockets/legacy/protocol.py:552, in WebSocketCommonProtocol.recv(self)
#     549 try:
#     550     # If asyncio.wait() is canceled, it doesn't cancel
#     551     # pop_message_waiter and self.transfer_data_task.
# --> 552     await asyncio.wait(
#     553         [pop_message_waiter, self.transfer_data_task],
#     554         return_when=asyncio.FIRST_COMPLETED,
#     555     )
#     556 finally:
#
# File ~/miniconda3/envs/experiments/lib/python3.10/asyncio/tasks.py:384, in wait(fs, timeout, return_when)
#     382 fs = {ensure_future(f, loop=loop) for f in fs}
# --> 384 return await _wait(fs, timeout, return_when, loop)
#
# File ~/miniconda3/envs/experiments/lib/python3.10/asyncio/tasks.py:491, in _wait(fs, timeout, return_when, loop)
#     490 try:
# --> 491     await waiter
#     492 finally:
#
# File ~/miniconda3/envs/experiments/lib/python3.10/asyncio/futures.py:285, in Future.__await__(self)
#     284     self._asyncio_future_blocking = True
# --> 285     yield self  # This tells Task to wait for completion.
#     286 if not self.done():
#
# File ~/miniconda3/envs/experiments/lib/python3.10/asyncio/tasks.py:304, in Task.__wakeup(self, future)
#     303 try:
# --> 304     future.result()
#     305 except BaseException as exc:
#     306     # This may also be a cancellation.
#
# File ~/miniconda3/envs/experiments/lib/python3.10/asyncio/futures.py:196, in Future.result(self)
#     195     exc = self._make_cancelled_error()
# --> 196     raise exc
#     197 if self._state != _FINISHED:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[9], line 20
#      18 sender_task = asyncio.create_task(websocket_send(websocket, response))
#      19 receiver_task = asyncio.create_task(receive_and_save_audio(websocket, wave_file))
# ---> 20 await asyncio.gather(sender_task, receiver_task)
#
# File ~/miniconda3/envs/experiments/lib/python3.10/asyncio/tasks.py:304, in Task.__wakeup(self, future)
#     302 def __wakeup(self, future):
#     303     try:
# --> 304         future.result()
#     305     except BaseException as exc:
#     306         # This may also be a cancellation.
#     307         self.__step(exc)
#
# CancelledError:
